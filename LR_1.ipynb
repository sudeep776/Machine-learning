# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('lr.csv')

# %%
df.head(5)
# Out:
#     x    y
# 0   1    3
# 1  10   20
# 2  20   90
# 3  40  110
# 4  50  130

# %%
x = df['x'].to_numpy()

# %%
y = df['y'].to_numpy()

# %%
x
# Out:
# array([  1,  10,  20,  40,  50,  70,  80,  90, 120], dtype=int64)

# %%
x = x.reshape(-1,1)

# %%
y = y.reshape(-1,1)

# %%
y = df['y'].to_numpy()

# %%
linreg = LinearRegression()

# %%
linreg.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred,color = 'red')

# %%
print(linreg.coef_)
# Out:
# [2.00488411]

# %%
print(linreg.intercept_)
# Out:
# 18.738971360549
